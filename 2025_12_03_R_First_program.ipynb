# %% [markdown]
# # Multiplication of 2 Numbers

# %%
3333 * 100
# Out:
# [1] 333300

# %%
4 - 2
# Out:
# [1] 2

# %%
a <- 5
a + 7
# Out:
# [1] 12

# %%
df = data.frame(Emp_name = c("Saad","Ahmad","Waqas"),
                Job_role = c("CEO","Manager","FCO")
                )
df
# Out:
#   Emp_name Job_role
# 1 Saad     CEO
# 2 Ahmad    Manager
# 3 Waqas    FCO
