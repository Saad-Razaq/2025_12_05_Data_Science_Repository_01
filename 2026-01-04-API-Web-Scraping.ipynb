# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # **Web Scraping Lab**

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab you will be:
#
# *   Familiar with the basics of the `BeautifulSoup` Python library
# *   Be able to scrape webpages for data and filter the data

# %% [markdown]
# <h2>Table of Contents</h2>
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ul>
#         <li>
#             <a href="#Beautiful-Soup-Object">Beautiful Soup Object</a>
#             <ul>
#                 <li><a href="#Tags">Tags</a></li>
#                 <li><a href="#Children,-Parents,-and-Siblings">Children, Parents, and Siblings</a></li>
#                 <li><a href="#HTML-Attributes">HTML Attributes</a></li>
#                 <li><a href="#Navigable-String">Navigable String</a></li>
#             </ul>
#         </li>
#      </ul>
#     <ul>
#         <li>
#             <a href="#Filter">Filter</a>
#             <ul>
#                 <li><a href="#find_All">find_All</a></li>
#                 <li><a href="#find">find</a></li>
#             </ul>
#         </li>
#      </ul>
#      <ul>
#         <li>
#             <a href="#Downloading-And-Scraping-The-Contents-Of-A-Web-Page">Downloading And Scraping The Contents Of A Web Page</a></li>
#          <li> <a href="#Scraping-tables-from-a-Web-page-using-Pandas">Scraping tables from a Web page using Pandas</a></li>
#     </ul>
#
# </div>
#
# <hr>

# %% [markdown]
# For this lab, we are going to be using Python and several Python libraries. Some of these libraries might be installed in your lab environment or in SN Labs. Others may need to be installed by you. The cells below will install these libraries when executed.

# %%
# !pip install html5lib
# Out:
# Requirement already satisfied: html5lib in c:\users\hp\anaconda3\envs\ibm_ds_2025\lib\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\users\hp\anaconda3\envs\ibm_ds_2025\lib\site-packages (from html5lib) (1.17.0)
# Requirement already satisfied: webencodings in c:\users\hp\anaconda3\envs\ibm_ds_2025\lib\site-packages (from html5lib) (0.5.1)

# %% [markdown]
# **Note:- After running the above code cell, restart the kernel and don't run the above code cell after restarting the kernel.**

# %%
# !pip install requests
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\anaconda3\envs\ibm_ds_2025\lib\site-packages (from bs4) (4.14.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\anaconda3\envs\ibm_ds_2025\lib\site-packages (from beautifulsoup4->bs4) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\hp\anaconda3\envs\ibm_ds_2025\lib\site-packages (from beautifulsoup4->bs4) (4.15.0)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %% [markdown]
# Import the required modules and functions

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page

# %%
url = 'https://petercorke.com/rvc3p/home/'

response = requests.get(url)

html_content = response.text

soup = BeautifulSoup(html_content,'html.parser')

print(html_content[:500])
# Out:
# 403 - Forbidden | Access to this page is forbidden.

# %% [markdown]
# ## Beautiful Soup Object

# %% [markdown]
# Beautiful Soup is a Python library for pulling data out of HTML and XML files, we will focus on HTML files. This is accomplished by representing the HTML as a set of objects with methods used to parse the HTML.  We can navigate the HTML as a tree, and/or filter out what we are looking for.
#
# Consider the following HTML:

# %%
# %%html
# <!DOCTYPE html>
# <html>
# <head>
# <title>Page Title</title>
# </head>
# <body>
# <h3><b id='boldest'>Lebron James</b></h3>
# <p> Salary: $ 92,000,000 </p>
# <h3> Stephen Curry</h3>
# <p> Salary: $85,000, 000 </p>
# <h3> Kevin Durant </h3>
# <p> Salary: $73,200, 000</p>
# </body>
# </html>

# %% [markdown]
# We can store it as a string in the variable HTML:

# %%
html = "<!DOCTYPE html><html><head><title>Page Title</title></head><body><h3> \
<b id='boldest'>Lebron James</b></h3><p> Salary: $ 92,000,000 </p> \
<h3>Stephen Curry</h3><p> Salary: $85,000,000</p> \
<h3>Kevin Durant</h3><p> Salary: $73,200,000</p></body></html>"

# %% [markdown]
# To parse a document, pass it into the <code>BeautifulSoup</code> constructor. The <code>BeautifulSoup</code> object represents the document as a nested data structure:

# %%
soup = BeautifulSoup(html, 'html5lib')

# %% [markdown]
# First, the document is converted to Unicode (similar to ASCII) and HTML entities are converted to Unicode characters. Beautiful Soup transforms a complex HTML document into a complex tree of Python objects. The <code>BeautifulSoup</code> object can create other types of objects. In this lab, we will cover <code>BeautifulSoup</code> and <code>Tag</code> objects, that for the purposes of this lab are identical. Finally, we will look at <code>NavigableString</code> objects.

# %% [markdown]
# We can use the method <code>prettify()</code> to display the HTML in the nested structure:

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Page Title
#   </title>
#  </head>
#  <body>
#   <h3>
#    <b id="boldest">
#     Lebron James
#    </b>
#   </h3>
#   <p>
#    Salary: $ 92,000,000
#   </p>
#   <h3>
#    Stephen Curry
#   </h3>
#   <p>
#    Salary: $85,000,000
#   </p>
#   <h3>
#    Kevin Durant
#   </h3>
#   <p>
#    Salary: $73,200,000
#   </p>
#  </body>
# </html>

# %% [markdown]
# ## Tags

# %% [markdown]
# Let's say we want the  title of the page and the name of the top paid player. We can use the <code>Tag</code>. The <code>Tag</code> object corresponds to an HTML tag in the original document, for example, the tag title.

# %%
tag_object = soup.title
print("tag object:", tag_object)
# Out:
# tag object: <title>Page Title</title>

# %% [markdown]
# we can see the tag type <code>bs4.element.Tag</code>

# %%
print("tag object type:", type(tag_object))
# Out:
# tag object type: <class 'bs4.element.Tag'>

# %% [markdown]
# If there is more than one <code>Tag</code> with the same name, the first element with that <code>Tag</code> name is called. This corresponds to the most paid player:

# %%
tag_object = soup.h3
tag_object
# Out:
# <h3> <b id="boldest">Lebron James</b></h3>

# %% [markdown]
# Enclosed in the bold attribute <code>b</code>, it helps to use the tree representation. We can navigate down the tree using the child attribute to get the name.

# %% [markdown]
# ### Children, Parents, and Siblings

# %% [markdown]
# As stated above, the <code>Tag</code> object is a tree of objects. We can access the child of the tag or navigate down the branch as follows:

# %%
tag_child = tag_object.b
print(tag_child)
# Out:
# <b id="boldest">Lebron James</b>

# %% [markdown]
# You can access the parent with the <code>parent</code>.

# %%
parent_tag = tag_child.parent
parent_tag
# Out:
# <h3> <b id="boldest">Lebron James</b></h3>

# %% [markdown]
# this is identical to:

# %%
tag_object
# Out:
# <h3> <b id="boldest">Lebron James</b></h3>

# %% [markdown]
# <code>tag_object</code> parent is the <code>body</code> element.

# %%
tag_object.parent
# Out:
# <body><h3> <b id="boldest">Lebron James</b></h3><p> Salary: $ 92,000,000 </p> <h3>Stephen Curry</h3><p> Salary: $85,000,000</p> <h3>Kevin Durant</h3><p> Salary: $73,200,000</p></body>

# %% [markdown]
# <code>tag_object</code> sibling is the <code>paragraph</code> element.

# %%
sibling_1 = tag_object.next_sibling
sibling_1
# Out:
# <p> Salary: $ 92,000,000 </p>

# %% [markdown]
# `sibling_2` is the `header` element, which is also a sibling of both `sibling_1` and `tag_object`

# %%
sibling_2 = sibling_1.next_sibling
print (sibling_2)

# %% [markdown]
# <h3 id="first_question">Exercise: <code>next_sibling</code></h3>

# %% [markdown]
# Use the object <code>sibling\_2</code> and the method <code>next_sibling</code> to find the salary of Stephen Curry:

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```
# sibling_2.next_sibling
#
# ```
#
# </details>

# %% [markdown]
# ### HTML Attributes

# %% [markdown]
# If the tag has attributes, the tag <code>id="boldest"</code> has an attribute <code>id</code> whose value is <code>boldest</code>. You can access a tag's attributes by treating the tag like a dictionary:

# %%
tag_child['id']
# Out:
# 'boldest'

# %% [markdown]
# You can access that dictionary directly as <code>attrs</code>:

# %%
tag_child.attrs
# Out:
# {'id': 'boldest'}

# %% [markdown]
# You can also work with Multi-valued attributes. Check out <a href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01">\[1]</a> for more.

# %% [markdown]
# We can also obtain the content of the attribute of the <code>tag</code> using the Python <code>get()</code> method.

# %%
tag_child.get('id')
# Out:
# 'boldest'

# %% [markdown]
# ### Navigable String

# %% [markdown]
# A string corresponds to a bit of text or content within a tag. Beautiful Soup uses the <code>NavigableString</code> class to contain this text. In our HTML we can obtain the name of the first player by extracting the string of the <code>Tag</code> object <code>tag_child</code> as follows:

# %%
tag_string = tag_child.string
tag_string
# Out:
# 'Lebron James'

# %% [markdown]
# we can verify the type is Navigable String

# %%
type(tag_string)
# Out:
# bs4.element.NavigableString

# %% [markdown]
# A NavigableString is similar to a Python string or Unicode string. To be more precise, the main difference is that it also supports some <code>BeautifulSoup</code> features. We can convert it to string object in Python:

# %%
unicode_string = str(tag_string)
unicode_string
# Out:
# 'Lebron James'

# %% [markdown]
# ## Filter

# %% [markdown]
# Filters allow you to find complex patterns, the simplest filter is a string. In this section we will pass a string to a different filter method and Beautiful Soup will perform a match against that exact string. Consider the following HTML of rocket launches:

# %%
# %%html
# <table>
#   <tr>
#     <td id='flight' >Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#    </tr>
#   <tr>
#     <td>1</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a></td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td>
#     <td>80 kg</td>
#   </tr>
# </table>

# %% [markdown]
# We can store it as a string in the variable <code>table</code>:

# %%
table = "<table><tr><td id='flight'>Flight No</td><td>Launch site</td> \
<td>Payload mass</td></tr><tr> <td>1</td> \
<td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a></td> \
<td>300 kg</td></tr><tr><td>2</td> \
<td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td> \
<td>94 kg</td></tr><tr><td>3</td> \
<td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td> \
<td>80 kg</td></tr></table>"

# %%
table_bs = BeautifulSoup(table, 'html5lib')

# %%
table_bs
# Out:
# <html><head></head><body><table><tbody><tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td> <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td> <td>300 kg</td></tr><tr><td>2</td> <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td> <td>94 kg</td></tr><tr><td>3</td> <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td> <td>80 kg</td></tr></tbody></table></body></html>

# %% [markdown]
# ## find_All

# %% [markdown]
# The <code>find_all()</code> method looks through a tag's descendants and retrieves all descendants that match your filters.
#
# <p>
# The Method signature for <code>find_all(name, attrs, recursive, string, limit, **kwargs)<c/ode>
# </p>

# %% [markdown]
# ### Name

# %% [markdown]
# When we set the <code>name</code> parameter to a tag name, the method will extract all the tags with that name and its children.

# %%
table_rows = table_bs.find_all('tr')
table_rows
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <tr> <td>1</td> <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td> <td>300 kg</td></tr>,
#  <tr><td>2</td> <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td> <td>94 kg</td></tr>,
#  <tr><td>3</td> <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td> <td>80 kg</td></tr>]

# %% [markdown]
# The result is a Python iterable just like a list, each element is a <code>tag</code> object:

# %%
first_row = table_rows[0]
first_row
# Out:
# <tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>

# %% [markdown]
# The type is <code>tag</code>

# %%
print(type(first_row))
# Out:
# <class 'bs4.element.Tag'>

# %% [markdown]
# we can obtain the child

# %%
first_row.td
# Out:
# <td id="flight">Flight No</td>

# %% [markdown]
# If we iterate through the list, each element corresponds to a row in the table:

# %%
for i, row in enumerate(table_rows):
    print("row", i, "is", row)
# Out:
# row 0 is <tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>
# row 1 is <tr> <td>1</td> <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td> <td>300 kg</td></tr>
# row 2 is <tr><td>2</td> <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td> <td>94 kg</td></tr>
# row 3 is <tr><td>3</td> <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td> <td>80 kg</td></tr>

# %% [markdown]
# As <code>row</code> is a <code>cell</code> object, we can apply the method <code>find_all</code> to it and extract table cells in the object <code>cells</code> using the tag <code>td</code>, this is all the children with the name <code>td</code>. The result is a list, each element corresponds to a cell and is a <code>Tag</code> object, we can iterate through this list as well. We can extract the content using the <code>string</code> attribute.

# %%
for i, row in enumerate(table_rows):
    print("row", i)
    cells = row.find_all('td')
    for j, cell in enumerate(cells):
        print('colunm', j, "cell", cell)
# Out:
# row 0
# colunm 0 cell <td id="flight">Flight No</td>
# colunm 1 cell <td>Launch site</td>
# colunm 2 cell <td>Payload mass</td>
# row 1
# colunm 0 cell <td>1</td>
# colunm 1 cell <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td>
# colunm 2 cell <td>300 kg</td>
# row 2
# colunm 0 cell <td>2</td>
# colunm 1 cell <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>
# colunm 2 cell <td>94 kg</td>
# row 3
# colunm 0 cell <td>3</td>
# colunm 1 cell <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td>
# colunm 2 cell <td>80 kg</td>

# %% [markdown]
# If we use a list we can match against any item in that list.

# %%
list_input = table_bs.find_all(name=["tr", "td"])
list_input
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <td id="flight">Flight No</td>,
#  <td>Launch site</td>,
#  <td>Payload mass</td>,
#  <tr> <td>1</td> <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td> <td>300 kg</td></tr>,
#  <td>1</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td>,
#  <td>300 kg</td>,
#  <tr><td>2</td> <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td> <td>94 kg</td></tr>,
#  <td>2</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>,
#  <td>94 kg</td>,
#  <tr><td>3</td> <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td> <td>80 kg</td></tr>,
#  <td>3</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td>,
#  <td>80 kg</td>]

# %% [markdown]
# ### Attributes

# %% [markdown]
# If the argument is not recognized it will be turned into a filter on the tag's attributes. For example with the <code>id</code> argument, Beautiful Soup will filter against each tag's <code>id</code> attribute. For example, the first <code>td</code> elements have a value of <code>id</code> of <code>flight</code>, therefore we can filter based on that <code>id</code> value.

# %%
table_bs.find_all(id="flight")
# Out:
# [<td id="flight">Flight No</td>]

# %% [markdown]
# We can find all the elements that have links to the Florida Wikipedia page:

# %%
list_input = table_bs.find_all(href="https://en.wikipedia.org/wiki/Florida")
list_input
# Out:
# [<a href="https://en.wikipedia.org/wiki/Florida">Florida</a>,
#  <a href="https://en.wikipedia.org/wiki/Florida">Florida</a>]

# %% [markdown]
# If we set the <code>href</code> attribute to True, regardless of what the value is, the code finds all anchor tags with <code>href</code> value:

# %%
table_bs.find_all('a', href=True)
# Out:
# [<a href="https://en.wikipedia.org/wiki/Florida">Florida</a>,
#  <a href="https://en.wikipedia.org/wiki/Texas">Texas</a>,
#  <a href="https://en.wikipedia.org/wiki/Florida">Florida</a>]

# %%
conda install -c conda-forge scrapy
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\HP\anaconda3\envs\IBM_DS_2025
#
#   added / updated specs:
#     - scrapy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     appdirs-1.4.4              |     pyhd8ed1ab_1          14 KB  conda-forge
#     automat-25.4.16            |     pyhd8ed1ab_0          41 KB  conda-forge
#     bcrypt-5.0.0               |  py313hfbe8231_1         167 KB  conda-forge
#     ca-certificates-2026.1.4   |       h4c7d964_0         144 KB  conda-forge
#     certifi-2026.1.4           |     pyhd8ed1ab_0         147 KB  conda-forge
#     constantly-15.1.0          |             py_0           9 KB  conda-forge
#     cryptography-46.0.3        |  py313hf5c5e30_1         1.4 MB  conda-forge
#     cssselect-1.3.0            |     pyhd8ed1ab_0          23 KB  conda-forge
#     filelock-3.20.2            |     pyhd8ed1ab_0          18 KB  conda-forge
#     hyperlink-21.0.0           |     pyh29332c3_1          73 KB  conda-forge
#     incremental-24.11.0        |     pyhcf101f3_0          27 KB  conda-forge
#     itemadapter-0.13.0         |     pyhd8ed1ab_0          40 KB  conda-forge
#     itemloaders-1.3.2          |     pyhd8ed1ab_1          30 KB  conda-forge
#     jmespath-1.0.1             |     pyhd8ed1ab_1          23 KB  conda-forge
#     libxslt-1.1.43             |       h25c3957_0         407 KB  conda-forge
#     lxml-6.0.2                 |  py313he881f1c_0         1.2 MB  conda-forge
#     openssl-3.6.0              |       h725018a_0         9.0 MB  conda-forge
#     parsel-1.10.0              |     pyhd8ed1ab_0          21 KB  conda-forge
#     protego-0.5.0              |     pyhd8ed1ab_0         2.3 MB  conda-forge
#     pyasn1-0.6.1               |     pyhd8ed1ab_2          61 KB  conda-forge
#     pyasn1-modules-0.4.2       |     pyhd8ed1ab_0          94 KB  conda-forge
#     pydispatcher-2.0.5         |             py_1          12 KB  conda-forge
#     pyopenssl-25.3.0           |     pyhd8ed1ab_0         123 KB  conda-forge
#     queuelib-1.8.0             |     pyhd8ed1ab_0          23 KB  conda-forge
#     requests-file-3.0.1        |     pyhd8ed1ab_0          11 KB  conda-forge
#     scrapy-2.13.4              |     pyhd8ed1ab_0         660 KB  conda-forge
#     service-identity-24.2.0    |     pyha770c72_1          16 KB  conda-forge
#     service_identity-24.2.0    |       hd8ed1ab_1           6 KB  conda-forge
#     tldextract-5.3.1           |     pyhd8ed1ab_0          99 KB  conda-forge
#     tomli-2.3.0                |     pyhcf101f3_0          20 KB  conda-forge
#     twisted-25.5.0             |  py313h5ea7bf4_1         6.2 MB  conda-forge
#     twisted-iocpsupport-25.10.1|  py313h5ea7bf4_0          46 KB  conda-forge
#     w3lib-2.3.1                |     pyhd8ed1ab_0          25 KB  conda-forge
#     zope.interface-8.0.1       |  py313h5fd188c_1         409 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        22.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   appdirs            conda-forge/noarch::appdirs-1.4.4-pyhd8ed1ab_1
#   automat            conda-forge/noarch::automat-25.4.16-pyhd8ed1ab_0
#   bcrypt             conda-forge/win-64::bcrypt-5.0.0-py313hfbe8231_1
#   constantly         conda-forge/noarch::constantly-15.1.0-py_0
#   cryptography       conda-forge/win-64::cryptography-46.0.3-py313hf5c5e30_1
#   cssselect          conda-forge/noarch::cssselect-1.3.0-pyhd8ed1ab_0
#   filelock           conda-forge/noarch::filelock-3.20.2-pyhd8ed1ab_0
#   hyperlink          conda-forge/noarch::hyperlink-21.0.0-pyh29332c3_1
#   incremental        conda-forge/noarch::incremental-24.11.0-pyhcf101f3_0
#   itemadapter        conda-forge/noarch::itemadapter-0.13.0-pyhd8ed1ab_0
#   itemloaders        conda-forge/noarch::itemloaders-1.3.2-pyhd8ed1ab_1
#   jmespath           conda-forge/noarch::jmespath-1.0.1-pyhd8ed1ab_1
#   libxslt            conda-forge/win-64::libxslt-1.1.43-h25c3957_0
#   lxml               conda-forge/win-64::lxml-6.0.2-py313he881f1c_0
#   parsel             conda-forge/noarch::parsel-1.10.0-pyhd8ed1ab_0
#   protego            conda-forge/noarch::protego-0.5.0-pyhd8ed1ab_0
#   pyasn1             conda-forge/noarch::pyasn1-0.6.1-pyhd8ed1ab_2
#   pyasn1-modules     conda-forge/noarch::pyasn1-modules-0.4.2-pyhd8ed1ab_0
#   pydispatcher       conda-forge/noarch::pydispatcher-2.0.5-py_1
#   pyopenssl          conda-forge/noarch::pyopenssl-25.3.0-pyhd8ed1ab_0
#   queuelib           conda-forge/noarch::queuelib-1.8.0-pyhd8ed1ab_0
#   requests-file      conda-forge/noarch::requests-file-3.0.1-pyhd8ed1ab_0
#   scrapy             conda-forge/noarch::scrapy-2.13.4-pyhd8ed1ab_0
#   service-identity   conda-forge/noarch::service-identity-24.2.0-pyha770c72_1
#   service_identity   conda-forge/noarch::service_identity-24.2.0-hd8ed1ab_1
#   tldextract         conda-forge/noarch::tldextract-5.3.1-pyhd8ed1ab_0
#   tomli              conda-forge/noarch::tomli-2.3.0-pyhcf101f3_0
#   twisted            conda-forge/win-64::twisted-25.5.0-py313h5ea7bf4_1
#   twisted-iocpsuppo~ conda-forge/win-64::twisted-iocpsupport-25.10.1-py313h5ea7bf4_0
#   w3lib              conda-forge/noarch::w3lib-2.3.1-pyhd8ed1ab_0
#   zope.interface     conda-forge/win-64::zope.interface-8.0.1-py313h5fd188c_1
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main/win-64::ca-certificates-202~ --> conda-forge/noarch::ca-certificates-2026.1.4-h4c7d964_0
#   certifi            pkgs/main/win-64::certifi-2025.11.12-~ --> conda-forge/noarch::certifi-2026.1.4-pyhd8ed1ab_0
#   openssl              pkgs/main::openssl-3.0.18-h543e019_0 --> conda-forge::openssl-3.6.0-h725018a_0
#
#
#
# Downloading and Extracting Packages: ...working...
# openssl-3.6.0        | 9.0 MB    |            |   0%
#
# twisted-25.5.0       | 6.2 MB    |            |   0%
#
#
# protego-0.5.0        | 2.3 MB    |            |   0%
#
#
#
# cryptography-46.0.3  | 1.4 MB    |            |   0%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    |            |   0%
#
#
#
#
#
# scrapy-2.13.4        | 660 KB    |            |   0%
#
#
#
#
#
#
# zope.interface-8.0.1 | 409 KB    |            |   0%
#
#
#
#
#
#
#
# libxslt-1.1.43       | 407 KB    |            |   0%
#
#
#
#
#
#
#
#
# bcrypt-5.0.0         | 167 KB    |            |   0%
#
#
#
#
#
#
#
#
#
# certifi-2026.1.4     | 147 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2026 | 144 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# pyopenssl-25.3.0     | 123 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# tldextract-5.3.1     | 99 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyasn1-modules-0.4.2 | 94 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hyperlink-21.0.0     | 73 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyasn1-0.6.1         | 61 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# twisted-iocpsupport- | 46 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# automat-25.4.16      | 41 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# itemadapter-0.13.0   | 40 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# protego-0.5.0        | 2.3 MB    |            |   1%
#
#
# protego-0.5.0        | 2.3 MB    | 2          |   3%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | 1          |   1%
#
#
# protego-0.5.0        | 2.3 MB    | 8          |   8%
#
#
# protego-0.5.0        | 2.3 MB    | #3         |  14%
#
#
# protego-0.5.0        | 2.3 MB    | #9         |  19%
#
#
# protego-0.5.0        | 2.3 MB    | ##2        |  23%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | 3          |   4%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | 9          |   9%
#
#
# protego-0.5.0        | 2.3 MB    | ##9        |  29%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | #          |  11%
#
#
# protego-0.5.0        | 2.3 MB    | #####1     |  51%
#
#
# protego-0.5.0        | 2.3 MB    | #####9     |  59%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | #5         |  16%
#
#
# protego-0.5.0        | 2.3 MB    | ######7    |  68%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | #8         |  19%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | ##1        |  21%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | ##3        |  24%
#
#
# protego-0.5.0        | 2.3 MB    | #######5   |  76%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | ##6        |  27%
#
#
# protego-0.5.0        | 2.3 MB    | ########2  |  82%
#
#
# protego-0.5.0        | 2.3 MB    | ########## | 100%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | ###3       |  33%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | ###7       |  37%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | ####1      |  41%
#
#
#
#
#
# scrapy-2.13.4        | 660 KB    | 2          |   2%
#
#
#
#
#
# scrapy-2.13.4        | 660 KB    | ###1       |  32%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | ####5      |  45%
#
#
#
#
#
# scrapy-2.13.4        | 660 KB    | #####5     |  56%
#
#
#
#
#
# scrapy-2.13.4        | 660 KB    | #######5   |  75%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | ####7      |  48%
#
#
#
#
#
# scrapy-2.13.4        | 660 KB    | ########## | 100%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | ######     |  61%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | ######7    |  68%
#
#
#
#
#
#
# zope.interface-8.0.1 | 409 KB    | 3          |   4%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | #######2   |  73%
#
#
#
#
#
#
# zope.interface-8.0.1 | 409 KB    | ###5       |  35%
#
#
#
#
#
#
# zope.interface-8.0.1 | 409 KB    | ######6    |  67%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | #######8   |  78%
#
#
#
#
#
#
# zope.interface-8.0.1 | 409 KB    | ########## | 100%
#
#
#
#
#
#
# zope.interface-8.0.1 | 409 KB    | ########## | 100%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | ########3  |  84%
#
#
#
#
#
#
#
# libxslt-1.1.43       | 407 KB    | 3          |   4%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | ########7  |  87%
#
#
#
#
#
#
#
# libxslt-1.1.43       | 407 KB    | ###1       |  31%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | #########1 |  91%
#
#
#
#
#
#
#
# libxslt-1.1.43       | 407 KB    | ######6    |  67%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | #########5 |  95%
#
#
#
#
#
#
#
# libxslt-1.1.43       | 407 KB    | ########## | 100%
#
#
#
#
#
#
#
# libxslt-1.1.43       | 407 KB    | ########## | 100%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | ########## | 100%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# bcrypt-5.0.0         | 167 KB    | 9          |  10%
#
#
#
#
#
#
#
#
# bcrypt-5.0.0         | 167 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# bcrypt-5.0.0         | 167 KB    | ########## | 100%
#
#
#
#
#
#
# zope.interface-8.0.1 | 409 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# certifi-2026.1.4     | 147 KB    | #          |  11%
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2026 | 144 KB    | #1         |  11%
#
#
#
#
#
#
#
#
#
# certifi-2026.1.4     | 147 KB    | ####3      |  43%
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2026 | 144 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# certifi-2026.1.4     | 147 KB    | ########6  |  87%
#
#
#
#
#
#
#
#
#
# certifi-2026.1.4     | 147 KB    | ########## | 100%
#
#
#
#
#
#
#
# libxslt-1.1.43       | 407 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# pyopenssl-25.3.0     | 123 KB    | #2         |  13%
#
#
#
#
#
#
#
#
#
#
#
# pyopenssl-25.3.0     | 123 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# tldextract-5.3.1     | 99 KB     | #6         |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyasn1-modules-0.4.2 | 94 KB     | #7         |  17%
#
#
#
#
#
#
#
#
#
#
#
#
# tldextract-5.3.1     | 99 KB     | ######4    |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyasn1-modules-0.4.2 | 94 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# tldextract-5.3.1     | 99 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hyperlink-21.0.0     | 73 KB     | ##1        |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyasn1-0.6.1         | 61 KB     | ##6        |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hyperlink-21.0.0     | 73 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyasn1-0.6.1         | 61 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# twisted-iocpsupport- | 46 KB     | ###4       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# twisted-iocpsupport- | 46 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# automat-25.4.16      | 41 KB     | ###9       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# automat-25.4.16      | 41 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# itemadapter-0.13.0   | 40 KB     | ###9       |  40%
#
#
#
#
# lxml-6.0.2           | 1.2 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# itemadapter-0.13.0   | 40 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
# bcrypt-5.0.0         | 167 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2026 | 144 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2026 | 144 KB    | ########## | 100%
#
#
#
#
#
# scrapy-2.13.4        | 660 KB    | ########## | 100%
#
#
#
#
#
# scrapy-2.13.4        | 660 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# certifi-2026.1.4     | 147 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# tldextract-5.3.1     | 99 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# tldextract-5.3.1     | 99 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# pyopenssl-25.3.0     | 123 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# pyopenssl-25.3.0     | 123 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hyperlink-21.0.0     | 73 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hyperlink-21.0.0     | 73 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyasn1-0.6.1         | 61 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyasn1-0.6.1         | 61 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# twisted-iocpsupport- | 46 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# twisted-iocpsupport- | 46 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyasn1-modules-0.4.2 | 94 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyasn1-modules-0.4.2 | 94 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# automat-25.4.16      | 41 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# automat-25.4.16      | 41 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# itemadapter-0.13.0   | 40 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# itemadapter-0.13.0   | 40 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# openssl-3.6.0        | 9.0 MB    |            |   0%
#
# twisted-25.5.0       | 6.2 MB    |            |   0%
#
#
#
# cryptography-46.0.3  | 1.4 MB    | 1          |   1%
# openssl-3.6.0        | 9.0 MB    |            |   1%
#
# twisted-25.5.0       | 6.2 MB    | 1          |   1%
#
#
#
# cryptography-46.0.3  | 1.4 MB    | 4          |   4%
# openssl-3.6.0        | 9.0 MB    | 1          |   1%
#
# twisted-25.5.0       | 6.2 MB    | 2          |   2%
# openssl-3.6.0        | 9.0 MB    | 2          |   2%
#
# twisted-25.5.0       | 6.2 MB    | 3          |   4%
#
#
#
# cryptography-46.0.3  | 1.4 MB    | 8          |   9%
# openssl-3.6.0        | 9.0 MB    | 3          |   3%
# openssl-3.6.0        | 9.0 MB    | 3          |   4%
#
# twisted-25.5.0       | 6.2 MB    | 4          |   4%
#
#
#
# cryptography-46.0.3  | 1.4 MB    | #7         |  18%
#
#
#
# cryptography-46.0.3  | 1.4 MB    | ##         |  21%
# openssl-3.6.0        | 9.0 MB    | 5          |   5%
#
# twisted-25.5.0       | 6.2 MB    | 5          |   5%
#
#
#
# cryptography-46.0.3  | 1.4 MB    | ##6        |  26%
#
#
#
# cryptography-46.0.3  | 1.4 MB    | ###        |  31%
# openssl-3.6.0        | 9.0 MB    | 6          |   6%
#
# twisted-25.5.0       | 6.2 MB    | 5          |   6%
# openssl-3.6.0        | 9.0 MB    | 9          |   9%
#
# twisted-25.5.0       | 6.2 MB    | 7          |   7%
#
#
#
# cryptography-46.0.3  | 1.4 MB    | ###4       |  34%
# openssl-3.6.0        | 9.0 MB    | #          |  10%
#
# twisted-25.5.0       | 6.2 MB    | 7          |   8%
# openssl-3.6.0        | 9.0 MB    | #4         |  14%
#
# twisted-25.5.0       | 6.2 MB    | #          |  10%
#
#
#
# cryptography-46.0.3  | 1.4 MB    | ####9      |  50%
#
# twisted-25.5.0       | 6.2 MB    | #1         |  11%
# openssl-3.6.0        | 9.0 MB    | #5         |  15%
#
#
#
# cryptography-46.0.3  | 1.4 MB    | #####6     |  56%
#
# twisted-25.5.0       | 6.2 MB    | #2         |  12%
# openssl-3.6.0        | 9.0 MB    | #9         |  19%
#
#
#
# cryptography-46.0.3  | 1.4 MB    | #######2   |  73%
#
# twisted-25.5.0       | 6.2 MB    | #5         |  15%
# openssl-3.6.0        | 9.0 MB    | ##1        |  21%
#
# twisted-25.5.0       | 6.2 MB    | #6         |  17%
#
#
#
# cryptography-46.0.3  | 1.4 MB    | #######9   |  79%
#
# twisted-25.5.0       | 6.2 MB    | #8         |  18%
#
# twisted-25.5.0       | 6.2 MB    | #9         |  19%
# openssl-3.6.0        | 9.0 MB    | ##2        |  23%
#
#
#
# cryptography-46.0.3  | 1.4 MB    | ########4  |  85%
# openssl-3.6.0        | 9.0 MB    | ##5        |  26%
#
# twisted-25.5.0       | 6.2 MB    | ##         |  20%
#
#
#
# cryptography-46.0.3  | 1.4 MB    | #########4 |  95%
#
# twisted-25.5.0       | 6.2 MB    | ##1        |  21%
# openssl-3.6.0        | 9.0 MB    | ##7        |  27%
#
# twisted-25.5.0       | 6.2 MB    | ##2        |  22%
# openssl-3.6.0        | 9.0 MB    | ##8        |  28%
#
#
#
# cryptography-46.0.3  | 1.4 MB    | #########9 |  99%
#
#
#
# cryptography-46.0.3  | 1.4 MB    | ########## | 100%
#
# twisted-25.5.0       | 6.2 MB    | ##5        |  25%
# openssl-3.6.0        | 9.0 MB    | ###2       |  33%
#
# twisted-25.5.0       | 6.2 MB    | ##6        |  27%
# openssl-3.6.0        | 9.0 MB    | ###4       |  35%
#
# twisted-25.5.0       | 6.2 MB    | ##7        |  28%
# openssl-3.6.0        | 9.0 MB    | ###6       |  36%
#
# twisted-25.5.0       | 6.2 MB    | ##9        |  29%
# openssl-3.6.0        | 9.0 MB    | ###7       |  38%
#
# twisted-25.5.0       | 6.2 MB    | ###        |  30%
# openssl-3.6.0        | 9.0 MB    | ###9       |  39%
#
# twisted-25.5.0       | 6.2 MB    | ###1       |  32%
# openssl-3.6.0        | 9.0 MB    | ####       |  41%
#
# twisted-25.5.0       | 6.2 MB    | ###2       |  33%
#
# twisted-25.5.0       | 6.2 MB    | ###3       |  34%
#
# twisted-25.5.0       | 6.2 MB    | ###4       |  35%
# openssl-3.6.0        | 9.0 MB    | ####1      |  42%
#
# twisted-25.5.0       | 6.2 MB    | ###5       |  36%
# openssl-3.6.0        | 9.0 MB    | ####5      |  45%
#
# twisted-25.5.0       | 6.2 MB    | ###6       |  37%
# openssl-3.6.0        | 9.0 MB    | ####7      |  47%
#
# twisted-25.5.0       | 6.2 MB    | ###7       |  38%
#
# twisted-25.5.0       | 6.2 MB    | ###8       |  39%
# openssl-3.6.0        | 9.0 MB    | ####8      |  49%
#
#
#
# cryptography-46.0.3  | 1.4 MB    | ########## | 100%
#
# twisted-25.5.0       | 6.2 MB    | ###9       |  40%
# openssl-3.6.0        | 9.0 MB    | #####      |  50%
# openssl-3.6.0        | 9.0 MB    | #####3     |  54%
#
# twisted-25.5.0       | 6.2 MB    | ####3      |  44%
#
# twisted-25.5.0       | 6.2 MB    | ####4      |  45%
#
# twisted-25.5.0       | 6.2 MB    | ####6      |  46%
# openssl-3.6.0        | 9.0 MB    | #####5     |  56%
#
# twisted-25.5.0       | 6.2 MB    | ####7      |  47%
# openssl-3.6.0        | 9.0 MB    | #####9     |  60%
#
# twisted-25.5.0       | 6.2 MB    | ####8      |  49%
# openssl-3.6.0        | 9.0 MB    | ######1    |  62%
#
# twisted-25.5.0       | 6.2 MB    | ####9      |  50%
#
# twisted-25.5.0       | 6.2 MB    | #####1     |  51%
# openssl-3.6.0        | 9.0 MB    | ######3    |  64%
#
# twisted-25.5.0       | 6.2 MB    | #####2     |  52%
# openssl-3.6.0        | 9.0 MB    | ######5    |  65%
#
# twisted-25.5.0       | 6.2 MB    | #####3     |  53%
# openssl-3.6.0        | 9.0 MB    | ######6    |  67%
#
# twisted-25.5.0       | 6.2 MB    | #####4     |  54%
# openssl-3.6.0        | 9.0 MB    | ######8    |  68%
#
# twisted-25.5.0       | 6.2 MB    | #####5     |  55%
# openssl-3.6.0        | 9.0 MB    | ######9    |  69%
#
# twisted-25.5.0       | 6.2 MB    | #####6     |  56%
# openssl-3.6.0        | 9.0 MB    | #######    |  71%
#
# twisted-25.5.0       | 6.2 MB    | #####7     |  57%
# openssl-3.6.0        | 9.0 MB    | #######2   |  72%
# openssl-3.6.0        | 9.0 MB    | #######4   |  74%
#
# twisted-25.5.0       | 6.2 MB    | #####9     |  60%
# openssl-3.6.0        | 9.0 MB    | #######9   |  79%
#
# twisted-25.5.0       | 6.2 MB    | ######1    |  61%
#
# twisted-25.5.0       | 6.2 MB    | ######2    |  62%
# openssl-3.6.0        | 9.0 MB    | ########1  |  82%
#
# twisted-25.5.0       | 6.2 MB    | ######3    |  63%
#
# twisted-25.5.0       | 6.2 MB    | ######4    |  64%
# openssl-3.6.0        | 9.0 MB    | ########3  |  84%
#
#
# protego-0.5.0        | 2.3 MB    | ########## | 100%
#
#
# protego-0.5.0        | 2.3 MB    | ########## | 100%
#
# twisted-25.5.0       | 6.2 MB    | #######1   |  71%
# openssl-3.6.0        | 9.0 MB    | #########2 |  92%
#
# twisted-25.5.0       | 6.2 MB    | #######3   |  74%
# openssl-3.6.0        | 9.0 MB    | #########7 |  97%
# openssl-3.6.0        | 9.0 MB    | #########9 | 100%
#
# twisted-25.5.0       | 6.2 MB    | #######5   |  75%
# openssl-3.6.0        | 9.0 MB    | ########## | 100%
#
# twisted-25.5.0       | 6.2 MB    | #######6   |  77%
#
# twisted-25.5.0       | 6.2 MB    | #######7   |  78%
#
# twisted-25.5.0       | 6.2 MB    | #######9   |  79%
#
# twisted-25.5.0       | 6.2 MB    | ########   |  80%
#
# twisted-25.5.0       | 6.2 MB    | ########1  |  82%
#
# twisted-25.5.0       | 6.2 MB    | ########2  |  83%
#
# twisted-25.5.0       | 6.2 MB    | ########4  |  84%
# openssl-3.6.0        | 9.0 MB    | ########## | 100%
#
# twisted-25.5.0       | 6.2 MB    | ########5  |  86%
#
# twisted-25.5.0       | 6.2 MB    | ########7  |  87%
#
# twisted-25.5.0       | 6.2 MB    | ########8  |  89%
#
# twisted-25.5.0       | 6.2 MB    | #########  |  90%
#
# twisted-25.5.0       | 6.2 MB    | #########1 |  92%
#
# twisted-25.5.0       | 6.2 MB    | #########3 |  94%
#
# twisted-25.5.0       | 6.2 MB    | #########5 |  95%
#
# twisted-25.5.0       | 6.2 MB    | #########7 |  97%
#
# twisted-25.5.0       | 6.2 MB    | #########9 |  99%
#
# twisted-25.5.0       | 6.2 MB    | ########## | 100%
#
# twisted-25.5.0       | 6.2 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.5.1
#     latest version: 25.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
import scrapy
class QuotesSpider(scrapy.Spider):
    name = 'quotes'
    start_urls = ['http://quotes.toscrape.com/tag/humor/',]
    def parse(self, response):
        for quote in response.css('div.quote'):
            yield {'quote':quote.css('span.text::text').get()}

# %%
conda install selenium
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\HP\anaconda3\envs\IBM_DS_2025
#
#   added / updated specs:
#     - selenium
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     outcome-1.3.0              |  py313haa95532_0          20 KB
#     selenium-4.38.0            |  py313h114bc41_0         2.7 MB
#     sortedcontainers-2.4.0     |     pyhd3eb1b0_0          26 KB
#     trio-0.32.0                |  py313haa95532_0         987 KB
#     trio-websocket-0.12.2      |  py313haa95532_1          59 KB
#     wsproto-1.3.1              |  py313haa95532_0          66 KB
#     ------------------------------------------------------------
#                                            Total:         3.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   outcome            pkgs/main/win-64::outcome-1.3.0-py313haa95532_0
#   selenium           pkgs/main/win-64::selenium-4.38.0-py313h114bc41_0
#   sortedcontainers   pkgs/main/noarch::sortedcontainers-2.4.0-pyhd3eb1b0_0
#   trio               pkgs/main/win-64::trio-0.32.0-py313haa95532_0
#   trio-websocket     pkgs/main/win-64::trio-websocket-0.12.2-py313haa95532_1
#   wsproto            pkgs/main/win-64::wsproto-1.3.1-py313haa95532_0
#
#
#
# Downloading and Extracting Packages: ...working...
# selenium-4.38.0      | 2.7 MB    |            |   0%
#
# trio-0.32.0          | 987 KB    |            |   0%
#
#
# wsproto-1.3.1        | 66 KB     |            |   0%
#
#
#
# trio-websocket-0.12. | 59 KB     |            |   0%
#
#
#
#
# sortedcontainers-2.4 | 26 KB     |            |   0%
#
#
#
#
#
# outcome-1.3.0        | 20 KB     |            |   0%
# selenium-4.38.0      | 2.7 MB    |            |   1%
#
#
#
#
# sortedcontainers-2.4 | 26 KB     | ######1    |  62%
#
#
#
#
# sortedcontainers-2.4 | 26 KB     | ########## | 100%
#
#
#
# trio-websocket-0.12. | 59 KB     | ##7        |  27%
#
# trio-0.32.0          | 987 KB    | 1          |   2%
#
#
#
# trio-websocket-0.12. | 59 KB     | ########## | 100%
#
#
# wsproto-1.3.1        | 66 KB     | ##4        |  24%
#
#
#
#
# sortedcontainers-2.4 | 26 KB     | ########## | 100%
#
#
#
#
# sortedcontainers-2.4 | 26 KB     | ########## | 100%
# selenium-4.38.0      | 2.7 MB    | 2          |   2%
#
# trio-0.32.0          | 987 KB    | 6          |   6%
#
#
#
# trio-websocket-0.12. | 59 KB     | ########## | 100%
#
#
#
# trio-websocket-0.12. | 59 KB     | ########## | 100%
#
# trio-0.32.0          | 987 KB    | #1         |  11%
#
#
# wsproto-1.3.1        | 66 KB     | #########6 |  97%
# selenium-4.38.0      | 2.7 MB    | 7          |   7%
#
#
#
#
#
# outcome-1.3.0        | 20 KB     | #######9   |  79%
#
#
# wsproto-1.3.1        | 66 KB     | ########## | 100%
#
#
#
#
#
# outcome-1.3.0        | 20 KB     | ########## | 100%
#
#
#
#
#
# outcome-1.3.0        | 20 KB     | ########## | 100%
#
#
#
#
#
# outcome-1.3.0        | 20 KB     | ########## | 100%
#
#
# wsproto-1.3.1        | 66 KB     | ########## | 100%
#
# trio-0.32.0          | 987 KB    | #4         |  15%
# selenium-4.38.0      | 2.7 MB    | #1         |  11%
#
# trio-0.32.0          | 987 KB    | ##5        |  26%
# selenium-4.38.0      | 2.7 MB    | ##         |  20%
#
# trio-0.32.0          | 987 KB    | ###8       |  39%
# selenium-4.38.0      | 2.7 MB    | ##6        |  26%
#
# trio-0.32.0          | 987 KB    | ####3      |  44%
# selenium-4.38.0      | 2.7 MB    | ###5       |  35%
#
# trio-0.32.0          | 987 KB    | #####5     |  55%
# selenium-4.38.0      | 2.7 MB    | ###9       |  40%
#
# trio-0.32.0          | 987 KB    | ######1    |  62%
# selenium-4.38.0      | 2.7 MB    | ####3      |  43%
#
# trio-0.32.0          | 987 KB    | ######6    |  66%
# selenium-4.38.0      | 2.7 MB    | ####6      |  47%
#
# trio-0.32.0          | 987 KB    | #######1   |  71%
# selenium-4.38.0      | 2.7 MB    | #####4     |  54%
#
# trio-0.32.0          | 987 KB    | ########4  |  84%
# selenium-4.38.0      | 2.7 MB    | #####9     |  60%
#
# trio-0.32.0          | 987 KB    | #########  |  91%
# selenium-4.38.0      | 2.7 MB    | ######4    |  64%
#
# trio-0.32.0          | 987 KB    | #########8 |  99%
#
# trio-0.32.0          | 987 KB    | ########## | 100%
# selenium-4.38.0      | 2.7 MB    | ######9    |  70%
# selenium-4.38.0      | 2.7 MB    | #######6   |  76%
# selenium-4.38.0      | 2.7 MB    | ########1  |  81%
# selenium-4.38.0      | 2.7 MB    | ########6  |  87%
# selenium-4.38.0      | 2.7 MB    | #########1 |  92%
# selenium-4.38.0      | 2.7 MB    | #########7 |  97%
# selenium-4.38.0      | 2.7 MB    | ########## | 100%
#
# trio-0.32.0          | 987 KB    | ########## | 100%
# selenium-4.38.0      | 2.7 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                       done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.5.1
#     latest version: 25.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
from selenium import webdriver

driver = webdriver.Firefox()
driver.get('http://www.example.com')

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Set a user agent to mimic a browser request
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

URL = 'https://en.wikipedia.org/wiki/List_of_largest_banks'

# Make a request with headers
response = requests.get(URL, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

# Use pandas to read the HTML with the headers
tables = pd.read_html(response.text)
df = tables[0]  # Assuming the first table is the one you want

print(df)
# Out:
#     Rank                                Bank name  \
# 0      1  Industrial and Commercial Bank of China
# 1      2               Agricultural Bank of China
# 2      3                  China Construction Bank
# 3      4                            Bank of China
# 4      5                           JPMorgan Chase
# ..   ...                                      ...
# 95    96                                SEB Group
# 96    97                         Raiffeisen Group
# 97    98                           Banco Bradesco
# 98    99                                 VTB Bank
# 99   100                     First Abu Dhabi Bank
#
#     Total assets (2025) (US$ billion)
# 0                             6688.74
# 1                             5923.76
# 2                             5558.38
# 3                             4803.51
# 4                             4002.81
# ..                                ...
# 95                             339.65
# 96                             337.25
# 97                             331.96
# 98                             330.43
# 99                             330.32
#
# [100 rows x 3 columns]
# C:\Users\HP\AppData\Local\Temp\ipykernel_17440\1258915020.py:17: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text)

# %% [markdown]
# There are other methods for dealing with attributes and other related methods. Check out the following <a href='https://www.crummy.com/software/BeautifulSoup/bs4/doc/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01#css-selectors'>link</a>

# %%
# Set a user agent to mimic a browser request
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

URL = 'https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)'


# Make a request with headers
response = requests.get(URL, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

# Use pandas to read the HTML with the headers
tables = pd.read_html(response.text)
df = tables[2]  # Assuming the first table is the one you want

print(df)
# Out:
#     Country/Territory IMF (2025)[6] World Bank (2024)[7]  \
# 0               World     117165394            111326370
# 1       United States      30615743             28750956
# 2          China[n 1]      19398577             18743803
# 3             Germany       5013574              4685593
# 4               Japan       4279828              4027598
# ..                ...           ...                  ...
# 217          Kiribati           321                  308
# 218  Marshall Islands           302                  290
# 219             Nauru           172                  163
# 220        Montserrat          —N/a                 —N/a
# 221            Tuvalu            58            62 (2023)
#
#     United Nations (2023)[8]
# 0                  100834796
# 1                   27720700
# 2                   17794782
# 3                    4525704
# 4                    4204495
# ..                       ...
# 217                      289
# 218                      270
# 219                      176
# 220                       80
# 221                       68
#
# [222 rows x 4 columns]
# C:\Users\HP\AppData\Local\Temp\ipykernel_17440\3114952082.py:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text)

# %% [markdown]
# <h3 id="exer_type">Exercise: <code>find_all</code></h3>

# %% [markdown]
# Using the logic above, find all the anchor tags without <code>href</code> value

# %%
# Add response here

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```
# table_bs.find_all('a', href=False)
#
# ```
#
# </details>

# %% [markdown]
# Using the soup object <code>soup</code>, find the element with the <code>id</code> attribute content set to <code>"boldest"</code>.

# %%
# Add your answer here

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```
# soup.find_all(id="boldest")
#
# ```
#
# </details>

# %% [markdown]
# ### string

# %% [markdown]
# With string you can search for strings instead of tags, where we find all the elments with Florida:

# %%
table_bs.find_all(string="Florida")

# %% [markdown]
# ## find

# %% [markdown]
# The <code>find_all()</code> method scans the entire document looking for results. It’s useful if you are looking for one element, as you can use the <code>find()</code> method to find the first element in the document. Consider the following two tables:

# %%
# %%html
# <h3>Rocket Launch </h3>
#
# <p>
# <table class='rocket'>
#   <tr>
#     <td>Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Florida</td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>Texas</td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>Florida </td>
#     <td>80 kg</td>
#   </tr>
# </table>
# </p>
# <p>
#
# <h3>Pizza Party</h3>
#
#
# <table class='pizza'>
#   <tr>
#     <td>Pizza Place</td>
#     <td>Orders</td>
#     <td>Slices </td>
#    </tr>
#   <tr>
#     <td>Domino's Pizza</td>
#     <td>10</td>
#     <td>100</td>
#   </tr>
#   <tr>
#     <td>Little Caesars</td>
#     <td>12</td>
#     <td >144 </td>
#   </tr>
#   <tr>
#     <td>Papa John's </td>
#     <td>15 </td>
#     <td>165</td>
#   </tr>

# %% [markdown]
# We store the HTML as a Python string and assign <code>two_tables</code>:

# %%
two_tables="<h3>Rocket Launch </h3> \
<p><table class='rocket'> \
<tr><td>Flight No</td><td>Launch site</td><td>Payload mass</td></tr> \
<tr><td>1</td><td>Florida</td><td>300 kg</td></tr> \
<tr><td>2</td><td>Texas</td><td>94 kg</td></tr> \
<tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table></p>\
<p><h3>Pizza Party</h3> \
<table class='pizza'> \
<tr><td>Pizza Place</td><td>Orders</td><td>Slices </td></tr> \
<tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr> \
<tr><td>Little Caesars</td><td>12</td><td >144 </td></tr> \
<tr><td>Papa John's</td><td>15 </td><td>165</td></tr>"

# %% [markdown]
# We create a <code>BeautifulSoup</code> object  <code>two_tables_bs</code>

# %%
two_tables_bs = BeautifulSoup(two_tables, 'html.parser')

# %% [markdown]
# We can find the first table using the tag name table

# %%
two_tables_bs.find("table")

# %% [markdown]
# We can filter on the class attribute to find the second table, but because class is a keyword in Python, we add an underscore to differentiate them.

# %%
two_tables_bs.find("table", class_='pizza')

# %% [markdown]
# <h2 id="DSCW">Downloading And Scraping The Contents Of A Web Page</h2>

# %% [markdown]
# We Download the contents of the web page:

# %%
url = "http://www.ibm.com"

# %% [markdown]
# We use <code>get</code> to download the contents of the webpage in text format and store in a variable called <code>data</code>:

# %%
data = requests.get(url).text

# %% [markdown]
# We create a <code>BeautifulSoup</code> object using the <code>BeautifulSoup</code> constructor

# %%
soup = BeautifulSoup(data, "html5lib")  # create a soup object using the variable 'data'

# %% [markdown]
# Scrape all links

# %%
for link in soup.find_all('a', href=True):  # in html anchor/link is represented by the tag <a>
    print(link.get('href'))

# %% [markdown]
# ### Scrape all images Tags

# %%
for link in soup.find_all('img'):  # in html image is represented by the tag <img>
    print(link)
    print(link.get('src'))

# %% [markdown]
# ### Scrape data from HTML tables

# %%
# The below url contains an html table with data about colors and color codes.
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

# %% [markdown]
# Before proceeding to scrape a web site, you need to examine the contents and the way data is organized on the website. Open the above url in your browser and check how many rows and columns there are in the color table.

# %%
# get the contents of the webpage in text format and store in a variable called data
data = requests.get(url).text

# %%
soup = BeautifulSoup(data, "html5lib")

# %%
# find a html table in the web page
table = soup.find('table')  # in html table is represented by the tag <table>

# %%
# Get all rows from the table
for row in table.find_all('tr'):  # in html table row represented by tag <tr>
    # Get all columns in each row.
    cols = row.find_all('td')  # in html a column is represented by tag <td>
    color_name = cols[2].string  # store the value in column 3 as color_name
    color_code = cols[3].text  # store the value in column 4 as color_code
    print("{}--->{}".format(color_name, color_code))

# %% [markdown]
# ## Scraping tables from a Web page using Pandas

# %% [markdown]
# Particularly for extracting tabular data from a web page, you may also use the `read_html()` method of the Pandas library.

# %%
# The below url contains an html table with data about colors and color codes.
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

# %% [markdown]
# You may extract all the tables from the given webpage simply by using the following commands.

# %%
import pandas as pd

tables = pd.read_html(url)
tables

# %% [markdown]
# `tables` is now a list of dataframes representing the tables from the web page, in the sequence of their appearance. In the current  URL, there is only a single table, so the same can be accessed as shown below.

# %%
tables[0]

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja
#
# Abhishek Gagneja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By            |          Change Description         |
# | ----------------- | ------- | ----------------------| ----------------------------------- |
# | 2023-11-02 | 1.1 | Abhishek Gagneja | Updated instructions, added web scraping using Pandas |
# | 2023-06-11        | 1.0     | Akansha Yadav         |   Spell check                       |
# | 2020-10-17        | 0.1     | Joseph Santarcangelo  |  Created initial version of the lab |

# %% [markdown]
# Copyright © 2023 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01).
